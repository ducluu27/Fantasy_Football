# %%
# Resources
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_2020 = pd.read_csv('Resources/FF_Stats_2020.csv')
df_2020.head()
# Out:
#    Rk          Player   Tm FantPos  Age   G  GS  Cmp  Att  Yds  TD  Int  \
# 0   1  Derrick Henry   TEN      RB   26  16  16    0    0    0   0    0
# 1   2   Alvin Kamara   NOR      RB   25  15  10    0    0    0   0    0
# 2   3     Dalvin Cook  MIN      RB   25  14  14    0    0    0   0    0
# 3   4   Davante Adams  GNB      WR   28  14  14    0    0    0   0    0
# 4   5    Travis Kelce  KAN      TE   31  15  15    1    2    4   0    0
#
#    Att.1  Yds.1   Y/A  TD.1  Tgt  Rec  Yds.2    Y/R  TD.2  Fmb  FL  TD.3  2PM  \
# 0    378   2027  5.36    17   31   19    114   6.00     0    3   2    17  1.0
# 1    187    932  4.98    16  107   83    756   9.11     5    1   0    21  NaN
# 2    312   1557  4.99    16   54   44    361   8.20     1    5   3    17  3.0
# 3      0      0   NaN     0  149  115   1374  11.95    18    1   1    18  NaN
# 4      0      0   NaN     0  145  105   1416  13.49    11    1   1    11  1.0
#
#    2PP  FantPt    PPR   DKPt   FDPt    VBD  PosRank  OvRank
# ...

# %%
df_2020.Player = df_2020.Player.str.rstrip()

# %%
df_2020_qb = df_2020.loc[df_2020['FantPos']=='QB']
df_2020_qb.head()
# Out:
#     Rk           Player   Tm FantPos  Age   G  GS  Cmp  Att   Yds  TD  Int  \
# 6    7       Josh Allen  BUF      QB   24  16  16  396  572  4544  37   10
# 7    8    Aaron Rodgers  GNB      QB   37  16  16  372  526  4299  48    5
# 8    9     Kyler Murray  ARI      QB   23  16  16  375  558  3971  26   12
# 9   10  Patrick Mahomes  KAN      QB   25  15  15  390  588  4740  38    6
# 10  11   Deshaun Watson  HOU      QB   25  16  16  382  544  4823  33    7
#
#     Att.1  Yds.1   Y/A  TD.1  Tgt  Rec  Yds.2   Y/R  TD.2  Fmb  FL  TD.3  2PM  \
# 6     102    421  4.13     8    1    1     12  12.0     1    9   6     9  NaN
# 7      38    149  3.92     3    1    1     -6  -6.0     0    4   2     3  NaN
# 8     133    819  6.16    11    0    0      0   NaN     0    9   4    11  NaN
# 9      62    308  4.97     2    2    0      0   NaN     0    5   2     2  NaN
# 10     90    444  4.93     3    0    0      0   NaN     0    8   3     3  NaN
#
# ...

# %%
df_2020_qb = df_2020_qb.drop(columns=['Tgt', 'Rec', 'Yds.2',
       'Y/R', 'TD.2', 'Fmb', 'FL', 'TD.3', '2PM', '2PP', 'FantPt', 'PPR',
       'DKPt', 'FDPt', 'VBD', 'OvRank'])
df_2020_qb.head(50)
# Out:
#       Rk              Player   Tm FantPos  Age   G  GS  Cmp  Att   Yds  TD  \
# 6      7          Josh Allen  BUF      QB   24  16  16  396  572  4544  37
# 7      8       Aaron Rodgers  GNB      QB   37  16  16  372  526  4299  48
# 8      9        Kyler Murray  ARI      QB   23  16  16  375  558  3971  26
# 9     10     Patrick Mahomes  KAN      QB   25  15  15  390  588  4740  38
# 10    11      Deshaun Watson  HOU      QB   25  16  16  382  544  4823  33
# 15    16      Russell Wilson  SEA      QB   32  16  16  384  558  4212  40
# 22    23      Ryan Tannehill  TEN      QB   32  16  16  315  481  3819  33
# 24    25           Tom Brady  TAM      QB   43  16  16  401  610  4633  40
# 28    29      Justin Herbert  LAC      QB   22  15  15  396  595  4336  31
# 29    30       Lamar Jackson  BAL      QB   23  15  15  242  376  2757  26
# 44    45        Kirk Cousins  MIN      QB   32  16  16  349  516  4265  35
# ...

# %%
#df_2020 = df_2020.drop(columns=['Rk', 'Tm'])
#df_2020.head()

# %%
#df_2020 = df_2020.set_index('Player')
#df_2020.head()

# %%
#df_2019 = pd.read_csv('Resources/FF_Stats_2019.csv')
#df_2019.head()

# %%
#df_2019 = df_2019.drop(columns=['Rk', 'Tm'])
#df_2019.head()

# %%
#df_2019 = df_2019.set_index('Player')
#df_2019.head()

# %%
#df_2018 = pd.read_csv('Resources/FF_Stats_2018.csv')
#df_2018.head()

# %%
#df_2018 = df_2018.drop(columns=['Rk', 'Tm'])
#df_2018.head()

# %%
#df_2018 = df_2018.set_index('Player')
#df_2018.head()

# %%
df_2020_qb.dtypes
# Out:
# Rk           int64
# Player      object
# Tm          object
# FantPos     object
# Age          int64
# G            int64
# GS           int64
# Cmp          int64
# Att          int64
# Yds          int64
# TD           int64
# Int          int64
# Att.1        int64
# Yds.1        int64
# Y/A        float64
# TD.1         int64
# PosRank      int64
# dtype: object

# %%
df_2020_qb = df_2020_qb.loc[df_2020['PosRank']<=15]
df_2020_qb.head()
# Out:
#     Rk           Player   Tm FantPos  Age   G  GS  Cmp  Att   Yds  TD  Int  \
# 6    7       Josh Allen  BUF      QB   24  16  16  396  572  4544  37   10
# 7    8    Aaron Rodgers  GNB      QB   37  16  16  372  526  4299  48    5
# 8    9     Kyler Murray  ARI      QB   23  16  16  375  558  3971  26   12
# 9   10  Patrick Mahomes  KAN      QB   25  15  15  390  588  4740  38    6
# 10  11   Deshaun Watson  HOU      QB   25  16  16  382  544  4823  33    7
#
#     Att.1  Yds.1   Y/A  TD.1  PosRank
# 6     102    421  4.13     8        1
# 7      38    149  3.92     3        2
# 8     133    819  6.16    11        3
# 9      62    308  4.97     2        4
# 10     90    444  4.93     3        5

# %%
df_2020_qb = df_2020_qb.set_index('Player')
df_2020_qb.head()
# Out:
#                  Rk   Tm FantPos  Age   G  GS  Cmp  Att   Yds  TD  Int  Att.1  \
# Player
# Josh Allen        7  BUF      QB   24  16  16  396  572  4544  37   10    102
# Aaron Rodgers     8  GNB      QB   37  16  16  372  526  4299  48    5     38
# Kyler Murray      9  ARI      QB   23  16  16  375  558  3971  26   12    133
# Patrick Mahomes  10  KAN      QB   25  15  15  390  588  4740  38    6     62
# Deshaun Watson   11  HOU      QB   25  16  16  382  544  4823  33    7     90
#
#                  Yds.1   Y/A  TD.1  PosRank
# Player
# Josh Allen         421  4.13     8        1
# Aaron Rodgers      149  3.92     3        2
# Kyler Murray       819  6.16    11        3
# Patrick Mahomes    308  4.97     2        4
# Deshaun Watson     444  4.93     3        5

# %%
df_2020_qb['TD_Cmp_Per'] = df_2020_qb['TD']/df_2020_qb['Cmp']

# %%
df_2020_qb.head(50)
# Out:
#                     Rk   Tm FantPos  Age   G  GS  Cmp  Att   Yds  TD  Int  \
# Player
# Josh Allen           7  BUF      QB   24  16  16  396  572  4544  37   10
# Aaron Rodgers        8  GNB      QB   37  16  16  372  526  4299  48    5
# Kyler Murray         9  ARI      QB   23  16  16  375  558  3971  26   12
# Patrick Mahomes     10  KAN      QB   25  15  15  390  588  4740  38    6
# Deshaun Watson      11  HOU      QB   25  16  16  382  544  4823  33    7
# Russell Wilson      16  SEA      QB   32  16  16  384  558  4212  40   13
# Ryan Tannehill      23  TEN      QB   32  16  16  315  481  3819  33    7
# Tom Brady           25  TAM      QB   43  16  16  401  610  4633  40   12
# Justin Herbert      29  LAC      QB   22  15  15  396  595  4336  31   10
# Lamar Jackson       30  BAL      QB   23  15  15  242  376  2757  26    9
# Kirk Cousins        45  MIN      QB   32  16  16  349  516  4265  35   13
# Matt Ryan           79  ATL      QB   35  16  16  407  626  4581  26   11
# ...

# %%
df_2020_qb.columns
# Out:
# Index(['Rk', 'Tm', 'FantPos', 'Age', 'G', 'GS', 'Cmp', 'Att', 'Yds', 'TD',
#        'Int', 'Att.1', 'Yds.1', 'Y/A', 'TD.1', 'PosRank', 'TD_Cmp_Per'],
#       dtype='object')

# %%
#all_df = [df_2020,df_2019,df_2018]
#merge_df = pd.concat(all_df)
#merge_df.head()

# %%
#merge_df.count()

# %%
#new_merge_df = merge_df.fillna(0)
#new_merge_df.head()

# %%
#new_merge_df.Player = new_merge_df.Player.str.rstrip()

# %%
#new_merge_df = new_merge_df.set_index('Player')
#new_merge_df.head()

# %%
#player_df = new_merge_df.groupby('Player').mean()
#player_df.head()

# %%
#new_player_df = player_df.dropna()
#new_player_df.head()

# %%
#new_merge_df = new_merge_df.dropna()
#new_merge_df.head(50)

# %%
#new_merge_df_cook = merge_df.loc[merge_df['Player'] == 'Jared Cook']
#new_merge_df_cook

# %%
#merge_df.head()

# %%
#new_merge_df.reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt
from matplotlib import pyplot

# %%
# Split data into training and testing
X = df_2020_qb[['Cmp', 'Att', 'Yds', 'TD',
       'Int', 'Att.1', 'Yds.1', 'Y/A','TD_Cmp_Per']]

y = df_2020_qb['PosRank']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(X_test)
print(y_predict)
# Out:
# [-11.36263948   8.03442624  15.5511049   14.39484139]

# %%
# Feature importance
# fit the model
model.fit(X_train, y_train)
# get importance
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print ('%30s, Score: %.5f' % (X_train.columns[i],v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
#                            Cmp, Score: -0.04605
#                            Att, Score: -0.13836
#                            Yds, Score: -0.00399
#                             TD, Score: 2.79648
#                            Int, Score: 0.01634
#                          Att.1, Score: -0.25213
#                          Yds.1, Score: 0.01581
#                            Y/A, Score: -0.19320
#                     TD_Cmp_Per, Score: -1231.88089

# %%
# Feature Importance into a dataframe
important_features = model.coef_
columns=X_train.columns
feature_import_df = pd.DataFrame({"feature":columns,"importance":important_features})
new_feature_df = feature_import_df.sort_values(by='importance',ascending=False)
new_feature_df = new_feature_df.round(5)
new_feature_df
# Out:
#       feature  importance
# 3          TD     2.79648
# 4         Int     0.01634
# 6       Yds.1     0.01581
# 2         Yds    -0.00399
# 0         Cmp    -0.04605
# 1         Att    -0.13836
# 7         Y/A    -0.19320
# 5       Att.1    -0.25213
# 8  TD_Cmp_Per -1231.88089

# %%
pd.set_option("max_rows", None)

# %%
results_df = pd.DataFrame(y_test)
results_df=results_df.sort_values(by=['PosRank'], ascending =False)
results_df
# Out:
#                     PosRank
# Player
# Ben Roethlisberger       14
# Derek Carr               13
# Lamar Jackson            10
# Aaron Rodgers             2
